# %%
import pandas as pd
import numpy as np

# %%
df_2019 = pd.read_csv('players_2019.csv')

# %%
df_2019.head()
# Out:
#    fide_id                name federation gender title   yob  year  month  \
# 0   100013  Campora, Daniel H.        ARG      M    GM  1957  2019      1
# 1   100013  Campora, Daniel H.        ARG      M    GM  1957  2019      2
# 2   100013  Campora, Daniel H.        ARG      M    GM  1957  2019      3
# 3   100013  Campora, Daniel H.        ARG      M    GM  1957  2019      4
# 4   100013  Campora, Daniel H.        ARG      M    GM  1957  2019      5
#
#    rating_standard
# 0           2417.0
# 1           2419.0
# 2           2405.0
# 3           2405.0
# 4           2420.0

# %%
grouped_df = df_2019.groupby("federation").mean()
grouped_df.head()
# Out:
#                  fide_id          yob    year  month  rating_standard
# federation
# AFG         1.025511e+06  1962.000000  2019.0    6.5      1528.000000
# AHO         1.026233e+06  1979.333333  2019.0    6.5      2054.666667
# ALB         8.213220e+05  1962.000000  2019.0    6.5      2406.000000
# ALG         6.422957e+05  1984.666667  2019.0    6.5      2103.277778
# AND         1.151490e+06  1968.000000  2019.0    6.5      2199.000000

# %%
sorted_df = grouped_df.sort_values(by=['month','rating_standard'], ascending=[True, False])
sorted_df.head(50)
# Out:
#                  fide_id          yob    year  month  rating_standard
# federation
# ARM         3.102040e+05  1978.000000  2019.0    6.5      2640.750000
# EGY         6.271430e+05  1987.000000  2019.0    6.5      2498.083333
# TUN         6.002290e+05  1962.000000  2019.0    6.5      2412.500000
# ALB         8.213220e+05  1962.000000  2019.0    6.5      2406.000000
# VIE         7.250560e+05  1973.000000  2019.0    6.5      2404.500000
# IRI         4.175210e+05  1993.000000  2019.0    6.5      2344.750000
# RUS         6.071280e+05  1973.666667  2019.0    6.5      2277.430556
# CAM         2.002264e+06  1961.500000  2019.0    6.5      2250.000000
# SUD         7.387940e+05  1996.000000  2019.0    6.5      2235.000000
# UKR         9.035400e+05  1968.000000  2019.0    6.5      2222.416667
# TUR         7.413768e+05  1974.750000  2019.0    6.5      2218.708333
# LTU         1.710828e+06  1972.500000  2019.0    6.5      2209.291667
# ...

# %%
df = pd.read_csv('players.csv')
df
# Out:
#           fide_id                   name federation gender title   yob
# 0          100013     Campora, Daniel H.        ARG      M    GM  1957
# 1          100021   Quinteros, Miguel A.        ARG      M    GM  1947
# 2          100048     Iapichello, Javier        ARG      M   NaN  1990
# 3          100064     Schipper, Bernardo        ARG      M   NaN  2000
# 4          100072            Adla, Diego        ARG      M    IM  1968
# ...           ...                    ...        ...    ...   ...   ...
# 433383  651079542      Teisseire, Armand        FRA      M   NaN  2006
# 433384  651080206         Lagarenne, Tom        FRA      M   NaN  1994
# 433385  651081628        Kratz, Jonathan        FRA      M   NaN  1988
# 433386  651081695          Bar, Francois        FRA      M   NaN  1965
# 433387  651081830  Martinati, Jean Louis        FRA      M   NaN  1965
#
# [433388 rows x 6 columns]
